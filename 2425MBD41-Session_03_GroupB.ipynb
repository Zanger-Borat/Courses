# %%
import pandas as pd

# %%
l = [[4, 7, 10],
     [5, 8, 11],
     [6, 9, 12]]

# %%
pd.DataFrame(l, columns=['a', 'b', 'c'], index=['Alice', 'Beth', 'Chris'])
# Out:
#        a  b   c
# Alice  4  7  10
# Beth   5  8  11
# Chris  6  9  12

# %%
pd.DataFrame({'a': [4, 5, 6],
              'b': [7, 8, 9],
              'c': [10, 11, 12]}, index=[1, 2, 3])
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2425MBD41_Demo_Data.xlsx',
                   sheet_name='Current Applications',
                   usecols=['SK_ID_CURR', 'TARGET', 'CODE_GENDER'],
                   nrows=10)

# %%
df
# Out:
#    SK_ID_CURR  TARGET CODE_GENDER
# 0      267142       0           F
# 1      344230       0           F
# 2      205422       0           M
# 3      103524       0           M
# 4      196457       0           M
# 5      399761       0           F
# 6      189184       0           F
# 7      454087       0           M
# 8      172131       0           M
# 9      159157       0           M

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/2425MBD41_Demo_Data_Exported.csv',
          index=False)

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2425MBD41_Demo_Data.xlsx',
                   sheet_name='Current Applications')

# %%
df
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 3070      299181       0         Cash loans           F          270000.0
# 3071      284339       0         Cash loans           M          121500.0
# 3072      297238       0         Cash loans           F          157500.0
# 3073      163329       0         Cash loans           F           99000.0
# 3074      308369       0    Revolving loans           F          180000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0      267142       0         Cash loans           F           49500.0
# 1      344230       0    Revolving loans           F          103500.0
# 2      205422       0         Cash loans           M          202500.0
# 3      103524       0         Cash loans           M          112500.0
# 4      196457       0         Cash loans           M          112500.0
#
#    AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# 0    473760.0  Secondary / secondary special      -23768             NaN
# 1    180000.0              Incomplete higher      -10346      Core staff
# 2    904608.0  Secondary / secondary special      -19321         Drivers
# 3    220500.0  Secondary / secondary special      -14489        Laborers
# 4    454500.0  Secondary / secondary special      -10423             NaN
#
#         ORGANIZATION_TYPE
# 0                     XNA
# 1  Business Entity Type 3
# ...

# %%
df.tail()
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 3070      299181       0         Cash loans           F          270000.0
# 3071      284339       0         Cash loans           M          121500.0
# 3072      297238       0         Cash loans           F          157500.0
# 3073      163329       0         Cash loans           F           99000.0
# 3074      308369       0    Revolving loans           F          180000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# 3070    503266.5               Higher education      -19730        Managers
# 3071    787131.0  Secondary / secondary special      -23540             NaN
# 3072    634482.0  Secondary / secondary special      -17368   Cooking staff
# 3073    448299.0  Secondary / secondary special      -14871        Laborers
# 3074    270000.0               Higher education       -9729     Accountants
#
#            ORGANIZATION_TYPE
# 3070              Government
# ...

# %%
df.shape
# Out:
# (3075, 10)

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'NAME_EDUCATION_TYPE', 'DAYS_BIRTH',
#        'OCCUPATION_TYPE', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SK_ID_CURR               int64
# TARGET                   int64
# NAME_CONTRACT_TYPE      object
# CODE_GENDER             object
# AMT_INCOME_TOTAL       float64
# AMT_CREDIT             float64
# NAME_EDUCATION_TYPE     object
# DAYS_BIRTH               int64
# OCCUPATION_TYPE         object
# ORGANIZATION_TYPE       object
# dtype: object

# %%
df.describe(include='all').T
# Out:
#                       count unique                            top  freq  \
# SK_ID_CURR           3075.0    NaN                            NaN   NaN
# TARGET               3075.0    NaN                            NaN   NaN
# NAME_CONTRACT_TYPE     3075      2                     Cash loans  2771
# CODE_GENDER            3075      2                              F  1980
# AMT_INCOME_TOTAL     3075.0    NaN                            NaN   NaN
# AMT_CREDIT           3075.0    NaN                            NaN   NaN
# NAME_EDUCATION_TYPE    3075      5  Secondary / secondary special  2160
# DAYS_BIRTH           3075.0    NaN                            NaN   NaN
# OCCUPATION_TYPE        2081     18                       Laborers   583
# ORGANIZATION_TYPE      3075     54         Business Entity Type 3   668
#
#                               mean            std       min       25%  \
# SK_ID_CURR           276257.810732  103173.542089  100004.0  186817.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3075 entries, 0 to 3074
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SK_ID_CURR           3075 non-null   int64
#  1   TARGET               3075 non-null   int64
#  2   NAME_CONTRACT_TYPE   3075 non-null   object
#  3   CODE_GENDER          3075 non-null   object
#  4   AMT_INCOME_TOTAL     3075 non-null   float64
#  5   AMT_CREDIT           3075 non-null   float64
#  6   NAME_EDUCATION_TYPE  3075 non-null   object
#  7   DAYS_BIRTH           3075 non-null   int64
#  8   OCCUPATION_TYPE      2081 non-null   object
#  9   ORGANIZATION_TYPE    3075 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 240.4+ KB

# %%
# select SK_ID_CURR, CODE_GENDER, AMT_INCOME_TOTAL from df;
cols = ['SK_ID_CURR', 'CODE_GENDER', 'AMT_INCOME_TOTAL']
df2 = df[cols]

# %%
df2
# Out:
#       SK_ID_CURR CODE_GENDER  AMT_INCOME_TOTAL
# 0         267142           F           49500.0
# 1         344230           F          103500.0
# 2         205422           M          202500.0
# 3         103524           M          112500.0
# 4         196457           M          112500.0
# ...          ...         ...               ...
# 3070      299181           F          270000.0
# 3071      284339           M          121500.0
# 3072      297238           F          157500.0
# 3073      163329           F           99000.0
# 3074      308369           F          180000.0
#
# [3075 rows x 3 columns]

# %%
df2.columns = ['ID', 'GENDER', 'INCOME']

# %%
df2
# Out:
#           ID GENDER    INCOME
# 0     267142      F   49500.0
# 1     344230      F  103500.0
# 2     205422      M  202500.0
# 3     103524      M  112500.0
# 4     196457      M  112500.0
# ...      ...    ...       ...
# 3070  299181      F  270000.0
# 3071  284339      M  121500.0
# 3072  297238      F  157500.0
# 3073  163329      F   99000.0
# 3074  308369      F  180000.0
#
# [3075 rows x 3 columns]

# %%
# select SK_ID_CURR, CODE_GENDER, AMT_INCOME_TOTAL from df;
cols = ['SK_ID_CURR', 'CODE_GENDER', 'AMT_INCOME_TOTAL']
df2 = df[cols]

# %%
df2.head()
# Out:
#    SK_ID_CURR CODE_GENDER  AMT_INCOME_TOTAL
# 0      267142           F           49500.0
# 1      344230           F          103500.0
# 2      205422           M          202500.0
# 3      103524           M          112500.0
# 4      196457           M          112500.0

# %%
df2 = df2.rename(columns={'AMT_INCOME_TOTAL': 'INCOME',
                    'CODE_GENDER': 'GENDER'})
# the same as
# df2.rename(columns={'AMT_INCOME_TOTAL': 'INCOME', 'CODE_GENDER': 'GENDER'}, inplace=True)

# %%
df2
# Out:
#       SK_ID_CURR GENDER    INCOME
# 0         267142      F   49500.0
# 1         344230      F  103500.0
# 2         205422      M  202500.0
# 3         103524      M  112500.0
# 4         196457      M  112500.0
# ...          ...    ...       ...
# 3070      299181      F  270000.0
# 3071      284339      M  121500.0
# 3072      297238      F  157500.0
# 3073      163329      F   99000.0
# 3074      308369      F  180000.0
#
# [3075 rows x 3 columns]

# %%
df2 = df2.rename(index=lambda x: x + 10)

# %%
df2
# Out:
#       SK_ID_CURR GENDER    INCOME
# 11        267143      F   49500.0
# 12        344231      F  103500.0
# 13        205423      M  202500.0
# 14        103525      M  112500.0
# 15        196458      M  112500.0
# ...          ...    ...       ...
# 3081      299182      F  270000.0
# 3082      284340      M  121500.0
# 3083      297239      F  157500.0
# 3084      163330      F   99000.0
# 3085      308370      F  180000.0
#
# [3075 rows x 3 columns]

# %%
df2 = df2.set_index('SK_ID_CURR')

# %%
df2
# Out:
#            GENDER    INCOME
# SK_ID_CURR
# 267142          F   49500.0
# 344230          F  103500.0
# 205422          M  202500.0
# 103524          M  112500.0
# 196457          M  112500.0
# ...           ...       ...
# 299181          F  270000.0
# 284339          M  121500.0
# 297238          F  157500.0
# 163329          F   99000.0
# 308369          F  180000.0
#
# [3075 rows x 2 columns]

# %%
df2 = df2.reset_index()

# %%
df2.iloc[3:5,]
# Out:
# 14    M
# 15    M
# Name: GENDER, dtype: object

# %%
# select * from df2 where INCOME > 200000;
df2[df2['INCOME'] > 200000]
# Out:
#       SK_ID_CURR GENDER    INCOME
# 13        205423      M  202500.0
# 17        189185      F  225000.0
# 18        454088      M  309150.0
# 21        205080      F  202500.0
# 22        103961      M  270000.0
# ...          ...    ...       ...
# 3074      230870      F  202500.0
# 3075      296816      M  382500.0
# 3079      335272      M  225000.0
# 3080      370198      M  225000.0
# 3081      299182      F  270000.0
#
# [912 rows x 3 columns]

# %%
# select GENDER from df2 where INCOME > 200000;
df2[df2['INCOME'] > 200000]['GENDER']
# same as
# df2['GENDER'][df2['INCOME'] > 200000]
# Out:
# 13      M
# 17      F
# 18      M
# 21      F
# 22      M
#        ..
# 3074    F
# 3075    M
# 3079    M
# 3080    M
# 3081    F
# Name: GENDER, Length: 912, dtype: object

# %%
# select * from df2 where INCOME > 200000 and GENDER = F;
c1 = (df2['INCOME']>200000)
c2 = (df2['GENDER']=='F')
df2[c1 & c2]
# Out:
#       SK_ID_CURR GENDER    INCOME
# 17        189185      F  225000.0
# 21        205080      F  202500.0
# 23        340121      F  202500.0
# 31        210941      F  202500.0
# 38        437056      F  225000.0
# ...          ...    ...       ...
# 3061      393972      F  202500.0
# 3063      374785      F  225000.0
# 3072      369753      F  247500.0
# 3074      230870      F  202500.0
# 3081      299182      F  270000.0
#
# [466 rows x 3 columns]

# %%
# select * from df2 where INCOME > 200000 or GENDER = F;
c1 = (df2['INCOME']>200000)
c2 = (df2['GENDER']=='F')
df2[c1 | c2]
# Out:
#       SK_ID_CURR GENDER    INCOME
# 11        267143      F   49500.0
# 12        344231      F  103500.0
# 13        205423      M  202500.0
# 16        399762      F   67500.0
# 17        189185      F  225000.0
# ...          ...    ...       ...
# 3080      370198      M  225000.0
# 3081      299182      F  270000.0
# 3083      297239      F  157500.0
# 3084      163330      F   99000.0
# 3085      308370      F  180000.0
#
# [2426 rows x 3 columns]

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0      267142       0         Cash loans           F           49500.0
# 1      344230       0    Revolving loans           F          103500.0
# 2      205422       0         Cash loans           M          202500.0
# 3      103524       0         Cash loans           M          112500.0
# 4      196457       0         Cash loans           M          112500.0
#
#    AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# 0    473760.0  Secondary / secondary special      -23768             NaN
# 1    180000.0              Incomplete higher      -10346      Core staff
# 2    904608.0  Secondary / secondary special      -19321         Drivers
# 3    220500.0  Secondary / secondary special      -14489        Laborers
# 4    454500.0  Secondary / secondary special      -10423             NaN
#
#         ORGANIZATION_TYPE
# 0                     XNA
# 1  Business Entity Type 3
# ...

# %%
df[df['NAME_EDUCATION_TYPE'].isin(['Secondary / secondary special', 'Incomplete higher'])]
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 3068      335271       0         Cash loans           M          225000.0
# 3069      370197       0    Revolving loans           M          225000.0
# 3071      284339       0         Cash loans           M          121500.0
# 3072      297238       0         Cash loans           F          157500.0
# 3073      163329       0         Cash loans           F           99000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...
