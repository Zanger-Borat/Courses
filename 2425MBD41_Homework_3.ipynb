# %% [markdown]
# # Introduction to Data Analytics Coding (Session 4)

# %%
import pandas as pd

# %% [markdown]
# ### 1. Load the entire "Current Applications" into (df1) and "Previous Applications" into (df2).

# %%
df1 = pd.read_excel("/content/2425MBD41_Demo_Data (3).xlsx",sheet_name = "Current Applications")
df2 = pd.read_excel("/content/2425MBD41_Demo_Data (3).xlsx",sheet_name = "Previous Applications")

# %%
df1
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 3070      299181       0         Cash loans           F          270000.0
# 3071      284339       0         Cash loans           M          121500.0
# 3072      297238       0         Cash loans           F          157500.0
# 3073      163329       0         Cash loans           F           99000.0
# 3074      308369       0    Revolving loans           F          180000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...

# %%
df2
# Out:
#        SK_ID_CURR  SK_ID_PREV NAME_CONTRACT_TYPE  AMT_APPLICATION  AMT_CREDIT  \
# 0          267142     2083552         Cash loans         270000.0    277308.0
# 1          267142     1539817     Consumer loans         257175.0    257175.0
# 2          344230     1598761     Consumer loans          30177.0     24138.0
# 3          344230     1156937     Consumer loans         246600.0    246600.0
# 4          205422     1080609     Consumer loans          18135.0     16861.5
# ...           ...         ...                ...              ...         ...
# 14827      163329     2148892     Consumer loans          38070.0     40333.5
# 14828      163329     1765034    Revolving loans          45000.0     45000.0
# 14829      163329     1696014         Cash loans         499500.0    558841.5
# 14830      163329     1090869         Cash loans         454500.0    544491.0
# 14831      308369     2333543     Consumer loans          72796.5     68976.0
#
# ...

# %% [markdown]
# ### 2. Get a dataframe (df3) with ORGANIZATION_TYPE containing "Transport"

# %%
df1.head()
df3= df1[df1["ORGANIZATION_TYPE"].str.contains("Transport",case = False, na = False)]
df3["ORGANIZATION_TYPE"] = df3["ORGANIZATION_TYPE"].str[0:9]
df3
# Out:
# <ipython-input-22-92dad00da95b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["ORGANIZATION_TYPE"] = df3["ORGANIZATION_TYPE"].str[0:9]
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 19        232052       1         Cash loans           M          216000.0
# 29        211065       0         Cash loans           M          180000.0
# 48        108150       1         Cash loans           M          202500.0
# 77        164268       1         Cash loans           F          202500.0
# 116       318788       1         Cash loans           M           81000.0
# ...          ...     ...                ...         ...               ...
# ...

# %% [markdown]
# ### 3. Create a new column OCCUPATION_TYPE_LEN in (df1) by counting the length of the string in OCCUPATION_TYPE

# %%
df1["OCCUPATION_TYPE_LEN"]= df1["OCCUPATION_TYPE"].str.len()
df1
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 3070      299181       0         Cash loans           F          270000.0
# 3071      284339       0         Cash loans           M          121500.0
# 3072      297238       0         Cash loans           F          157500.0
# 3073      163329       0         Cash loans           F           99000.0
# 3074      308369       0    Revolving loans           F          180000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...

# %% [markdown]
# ### 4. Show the number of records for each value of EDUCATION_TYPE in (df1)

# %%
df1.head()#We check if education type exists in dF as Education Type
df1["EDUCATION_TYPE"] = df1["NAME_EDUCATION_TYPE"]
df1["EDUCATION_TYPE"].value_counts()
# Out:
# EDUCATION_TYPE
# Secondary / secondary special    2160
# Higher education                  762
# Incomplete higher                 117
# Lower secondary                    34
# Academic degree                     2
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Get a new dataframe (df3) by sorting AMT_CREDIT in ascending order in (df1)

# %%
df3 = df1.set_index("AMT_CREDIT")
df3
# Out:
#             SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  \
# AMT_CREDIT
# 473760.0        267142       0         Cash loans           F
# 180000.0        344230       0    Revolving loans           F
# 904608.0        205422       0         Cash loans           M
# 220500.0        103524       0         Cash loans           M
# 454500.0        196457       0         Cash loans           M
# ...                ...     ...                ...         ...
# 503266.5        299181       0         Cash loans           F
# 787131.0        284339       0         Cash loans           M
# 634482.0        297238       0         Cash loans           F
# 448299.0        163329       0         Cash loans           F
# 270000.0        308369       0    Revolving loans           F
#
#             AMT_INCOME_TOTAL            NAME_EDUCATION_TYPE  DAYS_BIRTH  \
# AMT_CREDIT
# 473760.0             49500.0  Secondary / secondary special      -23768
# ...

# %% [markdown]
# ### 6. Get a dataframe (df3) with two columns (OCCUPATION_TYPE, ORGANIZATION_TYPE) and the duplicated records removed

# %%
cols = ["OCCUPATION_TYPE","ORGANIZATION_TYPE"]
df3 = df1[cols]
df3_filtered=df3.drop_duplicates()
df3_filtered
# Out:
#            OCCUPATION_TYPE       ORGANIZATION_TYPE
# 0                      NaN                     XNA
# 1               Core staff  Business Entity Type 3
# 2                  Drivers           Self-employed
# 3                 Laborers                   Other
# 4                      NaN                  Mobile
# ...                    ...                     ...
# 2919  Waiters/barmen staff     Security Ministries
# 3002        Cleaning staff           Trade: type 7
# 3007            Core staff               Emergency
# 3012        Security staff             Agriculture
# 3034           Sales staff           Trade: type 4
#
# [337 rows x 2 columns]

# %% [markdown]
# ### 7. Get a new dataframe (df3) with the average AMT_CREDIT by different OCCUPATION_TYPE in (df1)

# %%
df3=df1.groupby('OCCUPATION_TYPE')["AMT_CREDIT"].mean()
df3=df3.apply(lambda x: f"{x:.2f}")
print(df3)
#The results were not very clear so i tried to format it with a function.
# Out:
# OCCUPATION_TYPE
# Accountants               711397.49
# Cleaning staff            540527.33
# Cooking staff             515664.15
# Core staff                629785.86
# Drivers                   622086.42
# HR staff                 1096956.00
# High skill tech staff     622344.27
# IT staff                  582732.00
# Laborers                  574802.31
# Low-skill Laborers        366800.25
# Managers                  754592.62
# Medicine staff            654843.44
# Private service staff     600021.00
# Realty agents             686155.50
# Sales staff               588197.70
# Secretaries               839937.27
# Security staff            522794.08
# Waiters/barmen staff      651078.00
# Name: AMT_CREDIT, dtype: object

# %% [markdown]
# ### 8. Get a new dataframe (df3) with the number (count) of previous applications for different SK_ID_CURR in (df2)

# %%
df3=df2.groupby("SK_ID_CURR").size()
df3
#I was thinking of using .value_count but i gave me 1 each time so i moved to size()
# Out:
# SK_ID_CURR
# 100004    1
# 100381    2
# 100425    5
# 100440    5
# 100967    5
#          ..
# 455631    6
# 455684    5
# 455828    5
# 455877    4
# 456014    7
# Length: 2926, dtype: int64

# %% [markdown]
# ### 9. Merge (df1) and (df2) and get a new dataframe (df3) with the percentage of previously approved applications for different OCCUPATION_TYPE

# %%
df3=pd.merge(df1,df2, how="outer", on="SK_ID_CURR")
df_ok=df3[df3["NAME_CONTRACT_STATUS"]=="Approved"]

df3_ok=df3.groupby("OCCUPATION_TYPE")["NAME_CONTRACT_STATUS"].size()
df3=(df3_ok/df3_ok.sum())*100
percent_format = lambda x : f"{x:.1f}".replace(".", ",")+"%"
df3_formated = df3.apply(percent_format)
df3_formated
#I think it works, i divided df3.C by the sum of DFC and multiplied by 100. I did not found a way to apply a function That format to percentage
# Out:
# OCCUPATION_TYPE
# Accountants               4,9%
# Cleaning staff            2,0%
# Cooking staff             2,9%
# Core staff               12,0%
# Drivers                   9,6%
# HR staff                  0,1%
# High skill tech staff     4,7%
# IT staff                  0,2%
# Laborers                 29,1%
# Low-skill Laborers        0,9%
# Managers                  9,6%
# Medicine staff            3,8%
# Private service staff     0,8%
# Realty agents             0,5%
# Sales staff              14,6%
# Secretaries               0,3%
# Security staff            3,7%
# Waiters/barmen staff      0,3%
# Name: NAME_CONTRACT_STATUS, dtype: object

# %% [markdown]
# ### 10. Generate a horizontal bar chart for the frequency distribution of NAME_CONTRACT_STATUS in (df2)

# %%
STATUS_C = df2['NAME_CONTRACT_STATUS'].value_counts()
STATUS_C.plot.barh()
# Out:
# <Axes: ylabel='NAME_CONTRACT_STATUS'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
