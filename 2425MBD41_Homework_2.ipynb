# %% [markdown]
# # Introduction to Data Analytics Coding (Session 3)

# %%
import pandas as pd

# %% [markdown]
# ### 1. Import the demo data (Current Applications) with only the first 2000 rows to (df)

# %%
df = pd.read_excel("/content/2425MBD41_Demo_Data.xlsx", sheet_name= "Current Applications", nrows=2000)
df
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 1995      442960       0         Cash loans           M          292500.0
# 1996      318936       0         Cash loans           F          135000.0
# 1997      152503       0         Cash loans           M          112500.0
# 1998      285438       0         Cash loans           M          180000.0
# 1999      189812       0         Cash loans           F          450000.0
#
#       AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...

# %% [markdown]
# ### 2. Show a summary table of the data (including both numerical and categorical variables)

# %%
df.describe(include="all")
#Here we have all the data in its aspect
# Out:
#            SK_ID_CURR      TARGET NAME_CONTRACT_TYPE CODE_GENDER  \
# count     2000.000000  2000.00000               2000        2000
# unique            NaN         NaN                  2           2
# top               NaN         NaN         Cash loans           F
# freq              NaN         NaN               1810        1291
# mean    274816.122500     0.08150                NaN         NaN
# std     103651.070469     0.27367                NaN         NaN
# min     100004.000000     0.00000                NaN         NaN
# 25%     185056.250000     0.00000                NaN         NaN
# 50%     270991.500000     0.00000                NaN         NaN
# 75%     367201.500000     0.00000                NaN         NaN
# max     455877.000000     1.00000                NaN         NaN
#
#         AMT_INCOME_TOTAL    AMT_CREDIT            NAME_EDUCATION_TYPE  \
# count         2000.00000  2.000000e+03                           2000
# ...

# %% [markdown]
# ### 3. Change the column label "NAME_EDUCATION_TYPE" to "EDUCATION_TYPE"

# %%
# Let's check for the various head
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0      267142       0         Cash loans           F           49500.0
# 1      344230       0    Revolving loans           F          103500.0
# 2      205422       0         Cash loans           M          202500.0
# 3      103524       0         Cash loans           M          112500.0
# 4      196457       0         Cash loans           M          112500.0
#
#    AMT_CREDIT            NAME_EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# 0    473760.0  Secondary / secondary special      -23768             NaN
# 1    180000.0              Incomplete higher      -10346      Core staff
# 2    904608.0  Secondary / secondary special      -19321         Drivers
# 3    220500.0  Secondary / secondary special      -14489        Laborers
# 4    454500.0  Secondary / secondary special      -10423             NaN
#
#         ORGANIZATION_TYPE
# 0                     XNA
# 1  Business Entity Type 3
# ...

# %%
df=df.rename(columns={"NAME_EDUCATION_TYPE": "EDUCATION_TYPE"})
df
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# 0         267142       0         Cash loans           F           49500.0
# 1         344230       0    Revolving loans           F          103500.0
# 2         205422       0         Cash loans           M          202500.0
# 3         103524       0         Cash loans           M          112500.0
# 4         196457       0         Cash loans           M          112500.0
# ...          ...     ...                ...         ...               ...
# 1995      442960       0         Cash loans           M          292500.0
# 1996      318936       0         Cash loans           F          135000.0
# 1997      152503       0         Cash loans           M          112500.0
# 1998      285438       0         Cash loans           M          180000.0
# 1999      189812       0         Cash loans           F          450000.0
#
#       AMT_CREDIT                 EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# ...

# %% [markdown]
# ### 4. Set the index of the dataframe to "SK_ID_CURR"

# %%
df=df.set_index("SK_ID_CURR")

# %%
df
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 267142           0         Cash loans           F           49500.0
# 344230           0    Revolving loans           F          103500.0
# 205422           0         Cash loans           M          202500.0
# 103524           0         Cash loans           M          112500.0
# 196457           0         Cash loans           M          112500.0
# ...            ...                ...         ...               ...
# 442960           0         Cash loans           M          292500.0
# 318936           0         Cash loans           F          135000.0
# 152503           0         Cash loans           M          112500.0
# 285438           0         Cash loans           M          180000.0
# 189812           0         Cash loans           F          450000.0
#
#             AMT_CREDIT                 EDUCATION_TYPE  DAYS_BIRTH  \
# SK_ID_CURR
# ...

# %% [markdown]
# ### 5. Get a dataframe (df2) with EDUCATION_TYPE as "Lower secondary"

# %%
condition = (df['EDUCATION_TYPE']=='Lower secondary')
df2=df[condition]
df2
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 148747           0         Cash loans           F          121500.0
# 427522           0         Cash loans           F          112500.0
# 261051           0         Cash loans           F          157500.0
# 434171           0         Cash loans           F           58500.0
# 449171           0         Cash loans           M          135000.0
# 119037           0         Cash loans           M          135000.0
# 332251           0         Cash loans           M           94500.0
# 209586           1    Revolving loans           F           45000.0
# 158688           0         Cash loans           F          112500.0
# 271130           0         Cash loans           M          157500.0
# 215165           0         Cash loans           M          135000.0
# 232490           0         Cash loans           F          180000.0
# 161795           0         Cash loans           M          247500.0
# ...

# %% [markdown]
# ### 6. Get a dataframe (df2) with the applicants whose OCCUPATION_TYPE is not "Managers"

# %%
cond2 = (df['OCCUPATION_TYPE']!='Managers')
df2=df2[cond2]
df2
# Out:
# <ipython-input-42-bf90f926de28>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=df2[cond2]
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 148747           0         Cash loans           F          121500.0
# 427522           0         Cash loans           F          112500.0
# 261051           0         Cash loans           F          157500.0
# 434171           0         Cash loans           F           58500.0
# 449171           0         Cash loans           M          135000.0
# 119037           0         Cash loans           M          135000.0
# 332251           0         Cash loans           M           94500.0
# 209586           1    Revolving loans           F           45000.0
# 158688           0         Cash loans           F          112500.0
# 271130           0         Cash loans           M          157500.0
# 215165           0         Cash loans           M          135000.0
# ...

# %% [markdown]
# ### 7. Get a dataframe (df2) with EDUCATION_TYPE as either "Lower secondary" or "Secondary / secondary special"

# %%
cond3 = (df2["EDUCATION_TYPE"].isin(["Lower secondary", "Secondary / secondary special"]))
df2=df2[cond3]
df2
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 148747           0         Cash loans           F          121500.0
# 427522           0         Cash loans           F          112500.0
# 261051           0         Cash loans           F          157500.0
# 434171           0         Cash loans           F           58500.0
# 449171           0         Cash loans           M          135000.0
# 119037           0         Cash loans           M          135000.0
# 332251           0         Cash loans           M           94500.0
# 209586           1    Revolving loans           F           45000.0
# 158688           0         Cash loans           F          112500.0
# 271130           0         Cash loans           M          157500.0
# 215165           0         Cash loans           M          135000.0
# 232490           0         Cash loans           F          180000.0
# 161795           0         Cash loans           M          247500.0
# ...

# %% [markdown]
# ### 8. Get a dataframe (df2) with the applicant with AMT_INCOME_TOTAL between 100K and 200K (included)

# %%
df2["AMT_INCOME_TOTAL"].astype(float)
cond4 = (df2["AMT_INCOME_TOTAL"] >= 100000) & (df2["AMT_INCOME_TOTAL"] <= 200000)
df2 [cond4]
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 148747           0         Cash loans           F          121500.0
# 427522           0         Cash loans           F          112500.0
# 261051           0         Cash loans           F          157500.0
# 449171           0         Cash loans           M          135000.0
# 119037           0         Cash loans           M          135000.0
# 158688           0         Cash loans           F          112500.0
# 271130           0         Cash loans           M          157500.0
# 215165           0         Cash loans           M          135000.0
# 232490           0         Cash loans           F          180000.0
# 238778           0         Cash loans           M          157500.0
# 389876           0         Cash loans           M          135000.0
# 414155           1         Cash loans           F          157500.0
# 335789           0         Cash loans           F          135000.0
#
# ...

# %% [markdown]
# ### 9. Get a dataframe (df2) with only male applicants with AMT_INCOME_TOTAL less than 100K (included)

# %%
df2["AMT_INCOME_TOTAL"].astype(float)
cond5 = (df2['CODE_GENDER']=='M') & (df2['AMT_INCOME_TOTAL']<=100000)
df2[cond5]
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 332251           0         Cash loans           M           94500.0
# 152400           0         Cash loans           M           90000.0
# 130372           0         Cash loans           M           72000.0
#
#             AMT_CREDIT   EDUCATION_TYPE  DAYS_BIRTH OCCUPATION_TYPE  \
# SK_ID_CURR
# 332251        755190.0  Lower secondary      -21589             NaN
# 152400        508500.0  Lower secondary      -21912             NaN
# 130372        292500.0  Lower secondary      -14642        Laborers
#
#                  ORGANIZATION_TYPE
# SK_ID_CURR
# 332251                         XNA
# 152400                         XNA
# 130372      Business Entity Type 2

# %% [markdown]
# ### 10. Get a dataframe (df2) with three columns (SK_ID_CURR, TARGET, NAME_CONTRACT_TYPE) and only the applications for "Cash loans"

# %%
df2=df[['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE']]
cond6=(df2["NAME_CONTRACT_TYPE"]=="Cash loans")
df2_filt=df2[cond6]
df2_filt
# Out:
#       SK_ID_CURR  TARGET NAME_CONTRACT_TYPE
# 0         267142       0         Cash loans
# 2         205422       0         Cash loans
# 3         103524       0         Cash loans
# 4         196457       0         Cash loans
# 5         399761       0         Cash loans
# ...          ...     ...                ...
# 1995      442960       0         Cash loans
# 1996      318936       0         Cash loans
# 1997      152503       0         Cash loans
# 1998      285438       0         Cash loans
# 1999      189812       0         Cash loans
#
# [1810 rows x 3 columns]
