# %% [markdown]
# This is my first line of code.

# %%
x = 1

# %%
y = 'Python'

# %%
x = y = 5

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x = 2

# %%
x
# Out:
# 2

# %%
x += 1

# %%
x
# Out:
# 3

# %%
x += 1

# %%
x = 4

# %%
x *= 2

# %%
x
# Out:
# 8

# %%
x, y, z = 1, 2, 3

# %%
x, y, z
# Out:
# (1, 2, 3)

# %%
x, y = 1, 2

# %%
z = x

# %%
x = y

# %%
y = z

# %%
x, y
# Out:
# (2, 1)

# %%
x, y = 1, 2

# %%
x, y = y, x

# %%
x, y
# Out:
# (2, 1)

# %%
3 // 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
import numpy

# %%
import numpy as np

# %%
x = 'Python'

# %%
type(x)
# Out:
# str

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
m = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
m
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
m[0]
# Out:
# 'January'

# %%
m[1]
# Out:
# 'February'

# %%
m[11]
# Out:
# 'December'

# %%
m[-2]
# Out:
# 'November'

# %%
m[1:4]
# Out:
# ['February', 'March', 'April']

# %%
m[:4]
# Out:
# ['January', 'February', 'March', 'April']

# %%
m[-2:]
# Out:
# ['November', 'December']

# %%
m[1:6:2]
# Out:
# ['February', 'April', 'June']

# %%
m[1:6]
# Out:
# ['February', 'March', 'April', 'May', 'June']

# %%
list(reversed(m))
# Out:
# ['December',
#  'November',
#  'October',
#  'September',
#  'August',
#  'July',
#  'June',
#  'May',
#  'April',
#  'March',
#  'February',
#  'January']

# %%
m = m[::-1]

# %%
m
# Out:
# ['December',
#  'November',
#  'October',
#  'September',
#  'August',
#  'July',
#  'June',
#  'May',
#  'April',
#  'March',
#  'February',
#  'January']

# %%
x = [1, 2, [3, 4]]

# %%
len(x)
# Out:
# 3

# %%
type(x[1])
# Out:
# int

# %%
x[2][0]
# Out:
# 3

# %%
x = ['Hello', 'World']

# %%
'He' in x[0]
# Out:
# True

# %%
x = [1, 4, 3, 2, 5]

# %%
sorted(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
m = ('January', 'February', 'March', 'April', 'May', 'June', 'July',
     'August', 'September', 'October', 'November', 'December')

# %%
m[0]
# Out:
# 'January'

# %%
m[1]
# Out:
# 'February'

# %%
m[0] = 'Jan'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-0234148583ab> in <cell line: 1>()
# ----> 1 m[0] = 'Jan'
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
     'August', 'September', 'October', 'November', 'December']

# %%
l[0] = 'Jan'

# %%
l
# Out:
# ['Jan',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
x = (1,)

# %%
type(x)
# Out:
# tuple

# %%
x = "Hello World"

# %%
x = 'Hello World'

# %%
x = '''I'm happy with "Python"'''

# %%
print(x)
# Out:
# I'm happy with "Python"

# %%
x[4:9]
# Out:
# 'happy'

# %%
x[4:9] = 'unhappy'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-65f822a397bc> in <cell line: 1>()
# ----> 1 x[4:9] = 'unhappy'
#
# TypeError: 'str' object does not support item assignment

# %%
x = ['I', 'am', 'happy', 'with', 'python']

# %%
x[0] + ' ' + x[1] + ' ' + x[2]
# Out:
# 'I am happy'

# %%
z = ' '.join(x)

# %%
z.split()
# Out:
# ['I', 'am', 'happy', 'with', 'python']

# %%
x = ['1', '2', '3', '4', '5']

# %%
y = '+'.join(x)

# %%
y
# Out:
# '1+2+3+4+5'

# %%
y.split('+')
# Out:
# ['1', '2', '3', '4', '5']

# %%
z
# Out:
# 'I am happy with python'

# %%
z.replace('happy', 'unhappy')
# Out:
# 'I am unhappy with python'

# %%
z
# Out:
# 'I am happy with python'

# %%
x, y = 'Python', 'R'

# %%
x, y
# Out:
# ('Python', 'R')

# %%
f'I like {y} more than {x}'
# Out:
# 'I like R more than Python'

# %%
print('I like', x, 'more than', y)
# Out:
# I like Python more than R

# %%
from numpy import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
type(pi)
# Out:
# float

# %%
f'{pi:.10f}'
# Out:
# '3.1415926536'

# %%
lk = ['Alice', 'Beth', 'Cecil', 'Derek', 'Earl']

# %%
lv = ['2341', '9102', '3158', '0142', '5551']

# %%
d = {'Alice': '2341',
    'Beth': '9102',
    'Cecil': '3158',
    'Derek': '0142',
    'Earl': '5551'}

# %%
d['Derek'] = '1234'

# %%
d
# Out:
# {'Alice': '2341',
#  'Beth': '9102',
#  'Cecil': '3158',
#  'Derek': '1234',
#  'Earl': '5551'}

# %%
len(d)
# Out:
# 5

# %%
'Bob' in d
# Out:
# False

# %%
x = list(d.keys())

# %%
list(d.values())
# Out:
# ['2341', '9102', '3158', '1234', '5551']

# %%
type(tuple(x))
# Out:
# tuple

# %%
x = 'Derek'

# %%
list(x)
# Out:
# ['D', 'e', 'r', 'e', 'k']

# %%
x = dict(zip(lk, lv))

# %%
dict((('Alice', '2341'), ('Beth', '9102'),...))
# Out:
# {'Alice': '2341', 'Beth': '9102'}

# %%
x
# Out:
# {'Alice': '2341',
#  'Beth': '9102',
#  'Cecil': '3158',
#  'Derek': '0142',
#  'Earl': '5551'}

# %%
s = {'apple', 'orange', 'apple', 'pear', 'orange', 'banana'}

# %%
s
# Out:
# {'apple', 'banana', 'orange', 'pear'}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-c9c96910e542> in <cell line: 1>()
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1 = {"apple", "banana", "cherry"}
s2 = {"cat", "dog", "bird", "apple"}

# %%
s1.union(s2)
# Out:
# {'apple', 'banana', 'bird', 'cat', 'cherry', 'dog'}

# %%
s1.intersection(s2)
# Out:
# {'apple'}

# %%
s1.difference(s2)
# Out:
# {'banana', 'cherry'}

# %%
s2.difference(s1)
# Out:
# {'bird', 'cat', 'dog'}
